# %%
import csv
import json
import re
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from datetime import datetime
from preprocessing_func import process_corpus
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /userhome/2072/fyp21061/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /userhome/2072/fyp21061/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /userhome/2072/fyp21061/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /userhome/2072/fyp21061/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#Load the corpus and do the preprocessing
print("Loading Corpus and do the preprocessing")
Corpus=pd.read_json('./data/corpus-base.json')
Corpus=process_corpus(Corpus)
print(Corpus)
# Out:
# Loading Corpus and do the preprocessing
#                       Company Name Ticker      CIK formType  Filing Year  \
# 0      HENRY JACK & ASSOCIATES INC   JKHY   779152     10-K         2014
# 1        OSIRIS THERAPEUTICS, INC.   OSIR  1360886     10-K         2014
# 2    BARRETT BUSINESS SERVICES INC   BBSI   902791     10-K         2014
# 3      HENRY JACK & ASSOCIATES INC   JKHY   779152     10-K         2013
# 4    BARRETT BUSINESS SERVICES INC   BBSI   902791     10-K         2013
# ..                             ...    ...      ...      ...          ...
# 693         CONAGRA FOODS INC /DE/    CAG    23217     10-K         2014
# 694  MILLER ENERGY RESOURCES, INC.   MILL   785968     10-K         2014
# 695                           IXIA   XXIA  1120295     10-K         2014
# 696                      JBI, INC.         1381105     10-K         2014
# 697     LIFE PARTNERS HOLDINGS INC   LPHI    49534     10-K         2014
#
#      isFraud                                               MD&A  \
# 0          1  [item, managements, discussion, analysis, fina...
# 1          1  [item, managements, discussion, analysis, fina...
# 2          1  [item, managements, discussion, analysis, fina...
# 3          1  [item, managements, discussion, analysis, fina...
# 4          1  [item, managements, discussion, analysis, fina...
# ..       ...                                                ...
# 693        0  [item, managements, discussion, analysis, fina...
# 694        0                                        [undefined]
# 695        0  [item, managements, discussion, analysis, fina...
# 696        0  [item, managements, discussion, analysis, fina...
# 697        0  [item, managementrsquos, discussion, analysis,...
#
#                                         Tokenized_text
# 0    ['item', 'management', 'discussion', 'analysis...
# 1    ['item', 'management', 'discussion', 'analysis...
# 2    ['item', 'management', 'discussion', 'analysis...
# 3    ['item', 'management', 'discussion', 'analysis...
# 4    ['item', 'management', 'discussion', 'analysis...
# ..                                                 ...
# 693  ['item', 'management', 'discussion', 'analysis...
# 694                                      ['undefined']
# 695  ['item', 'management', 'discussion', 'analysis...
# 696  ['item', 'management', 'discussion', 'analysis...
# 697  ['item', 'managementrsquos', 'discussion', 'an...
#
# [698 rows x 8 columns]

# %%
print(Corpus['Tokenized_text'][0])
# Out:
# ['item', 'management', 'discussion', 'analysis', 'financial', 'condition', 'result', 'operation', 'follow', 'section', 'provide', 'management', 'view', 'financial', 'condition', 'result', 'operation', 'read', 'conjunction', 'select', 'financial', 'data', 'audit', 'consolidated', 'financial', 'statement', 'relate', 'note', 'include', 'elsewhere', 'report', 'overview', 'jack', 'henry', 'amp', 'associate', 'inc', 'jha', 'headquarter', 'monett', 'missouri', 'employ', 'approximately', 'associates', 'nationwide', 'lead', 'provider', 'technology', 'solution', 'payment', 'processing', 'service', 'primarily', 'financial', 'service', 'organization', 'solution', 'serve', 'nearly', 'customer', 'market', 'support', 'three', 'primary', 'brand', 'jack', 'henry', 'banking', 'support', 'bank', 'range', 'community', 'midtier', 'multibillion', 'dollar', 'institution', 'information', 'transaction', 'processing', 'solution', 'symitar', 'lead', 'provider', 'information', 'transaction', 'process', 'solution', 'credit', 'union', 'size', 'profitstars', 'provide', 'specialized', 'product', 'service', 'enable', 'financial', 'institution', 'every', 'asset', 'size', 'charter', 'diverse', 'corporate', 'entity', 'outside', 'financial', 'service', 'industry', 'mitigate', 'control', 'risk', 'optimize', 'revenue', 'growth', 'opportunity', 'contain', 'cost', 'jhas', 'integrated', 'solution', 'available', 'inhouse', 'installation', 'outsource', 'hosted', 'delivery', 'brand', 'share', 'fundamental', 'commitment', 'provide', 'high', 'quality', 'business', 'solution', 'service', 'level', 'consistently', 'exceed', 'customer', 'expectation', 'integration', 'solution', 'practical', 'new', 'technology', 'quality', 'solution', 'high', 'service', 'standard', 'fundamental', 'way', 'business', 'typically', 'foster', 'longterm', 'customer', 'relationship', 'attract', 'prospective', 'customer', 'enable', 'u', 'capture', 'substantial', 'market', 'share', 'internal', 'product', 'development', 'discipline', 'acquisition', 'alliance', 'company', 'offer', 'niche', 'solution', 'complement', 'proprietary', 'solution', 'regularly', 'introduce', 'new', 'product', 'service', 'generate', 'new', 'crosssales', 'opportunity', 'across', 'three', 'business', 'brand', 'provide', 'compatible', 'computer', 'hardware', 'inhouse', 'installation', 'secure', 'process', 'environment', 'outsource', 'hosted', 'solution', 'perform', 'data', 'conversion', 'software', 'implementation', 'initial', 'ongoing', 'customer', 'training', 'ongoing', 'customer', 'support', 'service', 'primary', 'competitive', 'advantage', 'customer', 'service', 'support', 'infrastructure', 'strict', 'standard', 'provide', 'service', 'level', 'believe', 'high', 'market', 'serve', 'generate', 'high', 'level', 'customer', 'satisfaction', 'retention', 'consistently', 'measure', 'customer', 'satisfaction', 'use', 'comprehensive', 'annual', 'survey', 'random', 'survey', 'receive', 'everyday', 'business', 'dedicate', 'survey', 'also', 'use', 'grade', 'specific', 'aspect', 'customer', 'experience', 'include', 'product', 'implementation', 'education', 'consulting', 'service', 'majority', 'revenue', 'derive', 'recur', 'outsource', 'fee', 'transaction', 'processing', 'fee', 'predominantly', 'contract', 'term', 'five', 'year', 'great', 'inception', 'support', 'service', 'fee', 'also', 'include', 'inhouse', 'maintenance', 'fee', 'primarily', 'annual', 'contract', 'term', 'less', 'predictable', 'software', 'license', 'fee', 'hardware', 'sale', 'complement', 'primary', 'revenue', 'source', 'continually', 'seek', 'opportunity', 'increase', 'revenue', 'time', 'contain', 'cost', 'expand', 'margin', 'last', 'five', 'fiscal', 'year', 'revenue', 'grow', 'fiscal', 'fiscal', 'income', 'continue', 'operation', 'grown', 'fiscal', 'fiscal', 'growth', 'result', 'primarily', 'internal', 'expansion', 'two', 'reportable', 'segment', 'bank', 'system', 'service', 'credit', 'union', 'system', 'service', 'respective', 'segment', 'include', 'related', 'license',  ...
